# %% [markdown]
# <img src="../assets/ga-logo.png" style="float: left; margin: 20px; height: 55px">
#
# # Introduction to `pandas`
#
# ---

# %% [markdown]
# ### About
# `pandas` is the most popular python package for managing datasets and is used extensively by data scientists.
#
# ### Learning Objectives
# - Explore the characteristics of a dataset at a high level with `pandas`.
#
# ### Notebook Guide
# An exercise in practising:
#
# - Reading data with `pandas`
# - Exploring and manipulating data with `pandas`
#     - Column operations
#     - Filtering
#     - Sorting
#     - Writing data

# %% [markdown]
# # Scenario
#
# You're an analyst working for CoolBricks - a new toy company who wants to compete with LEGO by producing their own bricks and sets. To better understand what kind of sets to create and at what price points, you are tasked with analyzing LEGO's catalogue over time.
#
# The data comes from Kaggle: [https://www.kaggle.com/datasets/alexracape/lego-sets-and-prices-over-time](https://www.kaggle.com/datasets/alexracape/lego-sets-and-prices-over-time)
#
# We are going to use `pandas` to read and explore this data.
#
# ### Business question
#
# What is the biggest set we could build (in terms of number of pieces) and what sort of price would we want to charge?

# %% [markdown]
# #### 1. Import `pandas` and read in the LEGO dataset

# %%
import pandas as pd 
lego=pd.read_csv('./data/lego.csv')
lego
# Out:
#          Set_ID                     Name  Year      Theme    Theme_Group  \
# 0          75-1            PreSchool Set  1975  PreSchool     Pre-school
# 1          77-1            PreSchool Set  1975  PreSchool     Pre-school
# 2         077-1           Pre-School Set  1975      Duplo     Pre-school
# 3          78-1            PreSchool Set  1975  PreSchool     Pre-school
# 4          78-3                Basic Set  1975  Samsonite        Vintage
# ...         ...                      ...   ...        ...            ...
# 14931  854242-1        Creeper Key Chain  2023       Gear  Miscellaneous
# 14932  854243-1          Steve Key Chain  2023       Gear  Miscellaneous
# 14933  854244-1         Piglin Key Chain  2023       Gear  Miscellaneous
# 14934  854245-1   Fennec Shand Key Chain  2023       Gear  Miscellaneous
# 14935  854246-1  Scout Trooper Key Chain  2023       Gear  Miscellaneous
#
#                    Subtheme Category        Packaging  Num_Instructions  \
# 0                       NaN   Normal  {Not specified}                 0
# 1                       NaN   Normal  {Not specified}                 0
# 2                       NaN   Normal  {Not specified}                 0
# 3                       NaN   Normal  {Not specified}                 0
# 4                 Basic set   Normal              Box                 0
# ...                     ...      ...              ...               ...
# 14931  Key Chains/Minecraft     Gear              Tag                 0
# 14932  Key Chains/Minecraft     Gear              Tag                 0
# 14933  Key Chains/Minecraft     Gear              Tag                 0
# 14934  Key Chains/Star Wars     Gear              Tag                 0
# 14935  Key Chains/Star Wars     Gear              Tag                 0
#
#           Availability  Pieces  Minifigures  Owned  Rating  USD_MSRP  \
# 0      {Not specified}    16.0          NaN   10.0     0.0       NaN
# 1      {Not specified}    20.0          NaN   11.0     0.0       NaN
# 2      {Not specified}    21.0          NaN   10.0     0.0       NaN
# 3      {Not specified}    32.0          NaN    8.0     0.0       NaN
# 4      {Not specified}   330.0          NaN   10.0     0.0       NaN
# ...                ...     ...          ...    ...     ...       ...
# 14931   LEGO exclusive     NaN          NaN    2.0     0.0      5.99
# 14932   LEGO exclusive     NaN          NaN    2.0     0.0      5.99
# 14933   LEGO exclusive     NaN          NaN    2.0     0.0      5.99
# 14934   LEGO exclusive     NaN          NaN   88.0     0.0      5.99
# 14935   LEGO exclusive     NaN          NaN  107.0     0.0      5.99
#
#        Total_Quantity  Current_Price
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 0.0            NaN
# 3                 NaN            NaN
# 4                 0.0            NaN
# ...               ...            ...
# 14931             NaN            NaN
# 14932             NaN            NaN
# 14933             NaN            NaN
# 14934             NaN            NaN
# 14935             NaN            NaN
#
# [14936 rows x 17 columns]

# %% [markdown]
# #### 2. So we can focus on just the columns that help answer the question, select only the following columns into a new `DataFrame` variable:
#
# - name
# - theme
# - number of pieces
# - retail price (USD_MSRP)

# %%
lego[['Name','Theme','Pieces','USD_MSRP']]
# Out:
#                           Name      Theme  Pieces  USD_MSRP
# 0                PreSchool Set  PreSchool    16.0       NaN
# 1                PreSchool Set  PreSchool    20.0       NaN
# 2               Pre-School Set      Duplo    21.0       NaN
# 3                PreSchool Set  PreSchool    32.0       NaN
# 4                    Basic Set  Samsonite   330.0       NaN
# ...                        ...        ...     ...       ...
# 14931        Creeper Key Chain       Gear     NaN      5.99
# 14932          Steve Key Chain       Gear     NaN      5.99
# 14933         Piglin Key Chain       Gear     NaN      5.99
# 14934   Fennec Shand Key Chain       Gear     NaN      5.99
# 14935  Scout Trooper Key Chain       Gear     NaN      5.99
#
# [14936 rows x 4 columns]

# %% [markdown]
# #### 3. How many sets have a price greater than $100?

# %%
(lego['USD_MSRP'] > 100).sum()
# Out:
# np.int64(380)

# %% [markdown]
# #### 4. What are the top 10 sets with the highest number of pieces?

# %%
lego.sort_values(by='Pieces', ascending=False).head(10)
# Out:
#         Set_ID                              Name  Year           Theme  \
# 13559  31203-1                         World Map  2021             Art
# 13946  10307-1                      Eiffel Tower  2022           Icons
# 13449  10294-1                           Titanic  2021           Icons
# 12942  10276-1                         Colosseum  2020           Icons
# 11928  75192-1                 Millennium Falcon  2017       Star Wars
# 14380  75331-1                   The Razor Crest  2022       Star Wars
# 14440  10316-1  The Lord of the Rings: Rivendell  2023           Icons
# 14807  71799-1              NINJAGO City Markets  2023         Ninjago
# 12369  71043-1                   Hogwarts Castle  2018    Harry Potter
# 11437  10256-1                         Taj Mahal  2017  Creator Expert
#
#             Theme_Group                   Subtheme Category Packaging  \
# 13559    Art and crafts              Miscellaneous   Normal       Box
# 13946      Model making                  Landmarks   Normal       Box
# 13449      Model making              Miscellaneous   Normal       Box
# 12942      Model making                  Landmarks   Normal       Box
# 11928          Licensed  Ultimate Collector Series   Normal       Box
# 14380          Licensed  Ultimate Collector Series   Normal       Box
# 14440      Model making                   Licensed   Normal       Box
# 14807  Action/Adventure             Dragons Rising   Normal       Box
# 12369          Licensed                    General   Normal       Box
# 11437      Model making                  Landmarks   Normal       Box
#
#        Num_Instructions    Availability   Pieces  Minifigures    Owned  \
# 13559                 7          Retail  11695.0          NaN   2677.0
# 13946                21  LEGO exclusive  10001.0          NaN   1825.0
# 13449                27  LEGO exclusive   9090.0          NaN   3994.0
# 12942                48  LEGO exclusive   9036.0          NaN   2883.0
# 11928                11  LEGO exclusive   7541.0          8.0  18898.0
# 14380                13  LEGO exclusive   6187.0          4.0   2732.0
# 14440                20  LEGO exclusive   6167.0         21.0   2104.0
# 14807                 0  LEGO exclusive   6163.0          NaN      8.0
# 12369                15  LEGO exclusive   6020.0         28.0  12937.0
# 11437                 2  LEGO exclusive   5923.0          NaN   4384.0
#
#        Rating  USD_MSRP  Total_Quantity  Current_Price
# 13559     4.0    249.99             3.0        199.000
# 13946     4.2    629.99             1.0        624.990
# 13449     4.6    679.99             8.0        640.000
# 12942     4.3    549.99             3.0        399.990
# 11928     4.6    849.99            10.0        700.000
# 14380     4.7    599.99             3.0        450.000
# 14440     4.7    499.99             3.0        420.390
# 14807     0.0    369.99             0.0            NaN
# 12369     4.5    469.99             7.0        350.991
# 11437     4.0    369.99             3.0        404.991

# %% [markdown]
# #### 5. Create a new column to measure "price per piece", which should be the price (USD_MSRP) divided by the number of pieces

# %%
lego['price_per_piece'] = lego['USD_MSRP'] / lego['Pieces']
lego.head()
# Out:
#   Set_ID            Name  Year      Theme Theme_Group   Subtheme Category  \
# 0   75-1   PreSchool Set  1975  PreSchool  Pre-school        NaN   Normal
# 1   77-1   PreSchool Set  1975  PreSchool  Pre-school        NaN   Normal
# 2  077-1  Pre-School Set  1975      Duplo  Pre-school        NaN   Normal
# 3   78-1   PreSchool Set  1975  PreSchool  Pre-school        NaN   Normal
# 4   78-3       Basic Set  1975  Samsonite     Vintage  Basic set   Normal
#
#          Packaging  Num_Instructions     Availability  Pieces  Minifigures  \
# 0  {Not specified}                 0  {Not specified}    16.0          NaN
# 1  {Not specified}                 0  {Not specified}    20.0          NaN
# 2  {Not specified}                 0  {Not specified}    21.0          NaN
# 3  {Not specified}                 0  {Not specified}    32.0          NaN
# 4              Box                 0  {Not specified}   330.0          NaN
#
#    Owned  Rating  USD_MSRP  Total_Quantity  Current_Price  price_per_piece
# 0   10.0     0.0       NaN             NaN            NaN              NaN
# 1   11.0     0.0       NaN             NaN            NaN              NaN
# 2   10.0     0.0       NaN             0.0            NaN              NaN
# 3    8.0     0.0       NaN             NaN            NaN              NaN
# 4   10.0     0.0       NaN             0.0            NaN              NaN

# %% [markdown]
# #### 6. Use this column to find the top 10 most expensive sets by "price per piece"

# %%
lego.sort_values(by='price_per_piece', ascending=False).head(10)
# Out:
#          Set_ID                                               Name  Year  \
# 13892  71394-11                 Character Pack Series 3 - Complete  2021
# 13806   66678-1  LEGO Minifigures - Marvel Studios Series {Box ...  2021
# 14251   66700-1  LEGO Minifigures - Series 22 {Box of 6 random ...  2022
# 9653    45500-1                              EV3 Intelligent Brick  2013
# 6342     9841-1                              NXT Intelligent Brick  2006
# 7695    10287-1                      Intelligent NXT Brick (Black)  2009
# 13755   45609-1                                          Small Hub  2021
# 9654    45501-1                            DC Rechargeable Battery  2013
# 8197     9693-1                        NXT DC Rechargeable Battery  2010
# 12927   88006-1                                          Boost Hub  2019
#
#                          Theme    Theme_Group                   Subtheme  \
# 13892              Super Mario       Licensed  Character Pack - Series 3
# 13806  Collectable Minifigures  Miscellaneous             Marvel Studios
# 14251  Collectable Minifigures  Miscellaneous                  Series 22
# 9653                Mindstorms      Technical                        EV3
# 6342                Mindstorms      Technical                        NXT
# 7695                Mindstorms      Technical                        NXT
# 13755                Education    Educational                      SPIKE
# 9654                 Education    Educational                 Mindstorms
# 8197                 Education    Educational                        NaN
# 12927               Powered Up      Technical                        NaN
#
#          Category        Packaging  Num_Instructions      Availability  \
# 13892  Collection  {Not specified}                 0            Retail
# 13806      Random              Box                 0  Retail - limited
# 14251      Random              Box                 0  Retail - limited
# 9653       Normal  {Not specified}                 0    LEGO exclusive
# 6342       Normal  {Not specified}                 0   {Not specified}
# 7695       Normal  {Not specified}                 0   {Not specified}
# 13755      Normal  {Not specified}                 0   {Not specified}
# 9654       Normal  {Not specified}                 0   {Not specified}
# 8197       Normal  {Not specified}                 0   {Not specified}
# 12927      Normal  {Not specified}                 0   {Not specified}
#
#        Pieces  Minifigures  Owned  Rating  USD_MSRP  Total_Quantity  \
# 13892     0.0         10.0  577.0     0.0      4.99             NaN
# 13806     0.0          NaN  261.0     0.0     29.94             1.0
# 14251     0.0          NaN  115.0     0.0     29.94             1.0
# 9653      1.0          NaN  113.0     0.0    224.95             1.0
# 6342      1.0          NaN  189.0     0.0    169.99             0.0
# 7695      1.0          NaN   99.0     0.0    169.99             1.0
# 13755     2.0          NaN   18.0     0.0    214.95             1.0
# 9654      1.0          NaN  179.0     0.0     99.95             0.0
# 8197      1.0          NaN  106.0     0.0     79.99             1.0
# 12927     1.0          NaN  117.0     0.0     79.99             1.0
#
#        Current_Price  price_per_piece
# 13892            NaN              inf
# 13806        39.5710              inf
# 14251        26.1573              inf
# 9653        160.0000          224.950
# 6342             NaN          169.990
# 7695        180.0000          169.990
# 13755       219.9500          107.475
# 9654             NaN           99.950
# 8197         45.9900           79.990
# 12927        50.0000           79.990

# %% [markdown]
# #### 7. Narrow the search to show the top 10 most expensive sets by "price per piece" for the "Icons" theme *only*

# %%
icons_only = lego[lego['Theme'] == 'Icons']
icons_only.sort_values(by='price_per_piece', ascending=False).head(10)
# Out:
#         Set_ID                             Name  Year  Theme   Theme_Group  \
# 13941  10302-1                    Optimus Prime  2022  Icons  Model making
# 13943  10304-1       Chevrolet Camaro Z/28 1969  2022  Icons  Model making
# 13450  10295-1                      Porsche 911  2021  Icons  Model making
# 13440  10282-1       Adidas Originals Superstar  2021  Icons  Model making
# 13939  10300-1  Back to the Future Time Machine  2022  Icons  Model making
# 13942  10303-1                     Loop Coaster  2022  Icons  Model making
# 14441  10317-1   Land Rover Classic Defender 90  2023  Icons  Model making
# 13446  10291-1       Queer Eye – The Fab 5 Loft  2021  Icons  Model making
# 12940  10274-1              Ghostbusters ECTO-1  2020  Icons  Model making
# 13617  40516-1              Everyone is Awesome  2021  Icons  Model making
#
#                     Subtheme Category Packaging  Num_Instructions  \
# 13941               Licensed   Normal       Box                 7
# 13943               Vehicles   Normal       Box                 9
# 13450               Vehicles   Normal       Box                 7
# 13440                 Adidas   Normal       Box                 8
# 13939               Vehicles   Normal       Box                 8
# 13942  Fairground Collection   Normal       Box                 2
# 14441               Vehicles   Normal       Box                 7
# 13446               Licensed   Normal       Box                 7
# 12940               Vehicles   Normal       Box                10
# 13617          Miscellaneous   Normal       Box                 2
#
#          Availability  Pieces  Minifigures    Owned  Rating  USD_MSRP  \
# 13941  LEGO exclusive  1508.0          NaN   6910.0     4.3    179.99
# 13943  LEGO exclusive  1456.0          NaN   3162.0     4.5    169.99
# 13450  LEGO exclusive  1458.0          NaN   8641.0     4.5    169.99
# 13440  LEGO exclusive   731.0          NaN   4064.0     4.2     79.99
# 13939  LEGO exclusive  1872.0          2.0   8363.0     4.6    199.99
# 13942  LEGO exclusive  3756.0         11.0   2865.0     4.6    399.99
# 14441  LEGO exclusive  2336.0          NaN    631.0     0.0    239.99
# 13446  LEGO exclusive   974.0          7.0   3507.0     4.1     99.99
# 12940  LEGO exclusive  2352.0          NaN  10585.0     4.4    239.99
# 13617  LEGO exclusive   346.0         11.0   9963.0     4.4     34.99
#
#        Total_Quantity  Current_Price  price_per_piece
# 13941             8.0       137.6700         0.119357
# 13943             0.0            NaN         0.116751
# 13450            12.0       131.2500         0.116591
# 13440             7.0        64.9500         0.109425
# 13939            12.0       159.9440         0.106832
# 13942             1.0       345.0000         0.106494
# 14441             0.0            NaN         0.102735
# 13446             1.0        65.0000         0.102659
# 12940             9.0       218.1427         0.102037
# 13617            15.0        39.5000         0.101127

# %% [markdown]
# #### 8. What are the top 10 cheapest sets by "price per piece" in the "Icons" theme?

# %%
icons_only = lego[lego['Theme'] == 'Icons']
icons_only.sort_values(by='price_per_piece', ascending=True).head(10)
# Out:
#         Set_ID                                     Name  Year  Theme  \
# 13439  10281-1                              Bonsai Tree  2021  Icons
# 14576  40646-1                                Daffodils  2023  Icons
# 12942  10276-1                                Colosseum  2020  Icons
# 14438  10314-1                 Dried Flower Centrepiece  2023  Icons
# 13946  10307-1                             Eiffel Tower  2022  Icons
# 13443  10284-1                  Camp Nou - FC Barcelona  2021  Icons
# 14437  10313-1                       Wildflower Bouquet  2023  Icons
# 13948  10309-1                               Succulents  2022  Icons
# 13947  10308-1                      Holiday Main Street  2022  Icons
# 13938  10299-1  Real Madrid - Santiago Bernabéu Stadium  2022  Icons
#
#         Theme_Group                   Subtheme Category Packaging  \
# 13439  Model making       Botanical Collection   Normal       Box
# 14576  Model making       Botanical Collection   Normal       Box
# 12942  Model making                  Landmarks   Normal       Box
# 14438  Model making       Botanical Collection   Normal       Box
# 13946  Model making                  Landmarks   Normal       Box
# 13443  Model making                   Stadiums   Normal       Box
# 14437  Model making       Botanical Collection   Normal       Box
# 13948  Model making       Botanical Collection   Normal       Box
# 13947  Model making  Winter Village Collection   Normal       Box
# 13938  Model making                   Stadiums   Normal       Box
#
#        Num_Instructions    Availability   Pieces  Minifigures    Owned  \
# 13439                11          Retail    878.0          NaN  17980.0
# 14576                 2          Retail    216.0          NaN   2944.0
# 12942                48  LEGO exclusive   9036.0          NaN   2883.0
# 14438                14          Retail    812.0          NaN   2349.0
# 13946                21  LEGO exclusive  10001.0          NaN   1825.0
# 13443                14  LEGO exclusive   5509.0          NaN   1400.0
# 14437                 7          Retail    939.0          NaN   3502.0
# 13948                21          Retail    771.0          NaN   7180.0
# 13947                28  LEGO exclusive   1514.0          6.0   6474.0
# 13938                14  LEGO exclusive   5876.0          NaN    550.0
#
#        Rating  USD_MSRP  Total_Quantity  Current_Price  price_per_piece
# 13439     4.4     49.99            12.0          31.20         0.056936
# 14576     3.8     12.99            11.0          14.00         0.060139
# 12942     4.3    549.99             3.0         399.99         0.060867
# 14438     0.0     49.99             2.0          43.98         0.061564
# 13946     4.2    629.99             1.0         624.99         0.062993
# 13443     4.3    349.99             5.0         330.00         0.063531
# 14437     4.3     59.99             2.0          47.95         0.063887
# 13948     4.3     49.99             3.0          57.00         0.064838
# 13947     4.1     99.99            13.0          78.82         0.066044
# 13938     0.0    399.99             0.0            NaN         0.068072

# %% [markdown]
# #### 9. Export the `DataFrame` you created in question 2. to a new CSV file.

# %%
lego.to_csv('lego_subset.csv', index=False)

# %% [markdown]
# ### Reflection
#
# What is your answer to the business question? Here it is as a reminder:
#
# > What is the biggest set we could build (in terms of number of pieces) and what sort of price would we want to charge?
#
# Reflect on your experience. How was working with `pandas` compared to other tools you already know?
