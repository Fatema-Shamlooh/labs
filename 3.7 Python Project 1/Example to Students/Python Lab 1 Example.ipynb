# %% [markdown]
#  ## Everytime you change something in my_func.py you must restart the kernel and reimport (import my_func) before you rerun

# %%
import my_func

# %%
my_func.main()
# Out:
# Welcome to Habit Tracker!
# This app helps you build and maintain positive habits.
#
# === Habit Tracker ===
# 1. Add a new habit to track
# 2. Log completion of a habit
# 3. View habit streaks and statistics
# 4. Edit or remove habits
# 5. View all habits
# 6. Visualize habits (calendar view)
# 7. View rewards
# 8. Exit
# Enter your choice (1-8):  4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 my_func.main()
#
# File ~\GA_DSB\practice\Python Project 1\Example to Students\my_func.py:112, in main()
#     110     view_streaks_and_statistics()
#     111 elif choice == '4':
# --> 112     edit_or_remove_habits()
#     113 elif choice == '5':
#     114     view_all_habits()
#
# NameError: name 'edit_or_remove_habits' is not defined
